# %% [markdown]
# # QA Experiment - 4 levels

# %% [markdown]
# - Using 4 level answers with ChatGPT-4o-mini
#
# Prompt available at: experiments\templates\

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# Loading internal package

# %%
import clizod_ranker as cr

# %%
import os
import re
import shutil
import pandas as pd
import re
import numpy as np
import json
import asyncio
import time
import datetime

from random import randrange
from os.path import join, exists

# %% [markdown]
# ## Load Data
# Loading the cleaned data

# %%
input_file_path = '../data/data_01_cleaned.csv'
df_sample = pd.read_csv(input_file_path)

print(f"There are {len(df_sample)} rows in this dataset.")
df_sample.head(3)
# Out:
# There are 2905 rows in this dataset.
#    tag disease  variable                       target_hash  \
# 0  0.0    cchf  rainfall  1266833a0c9bd183b54db85128f28024
# 1  0.0    cchf  rainfall  c025b214c7370b24a3776e85f6cd285b
# 2  0.0    cchf  rainfall  273c3107270be7343e0e43692cde82c3
#
#                                               target  review        reference  \
# 0  Scientific Opinion on the Role of Tick Vectors...     1.0  Journal Article
# 1  A survey of rift valley fever and associated r...     0.0  Journal Article
# 2  Occurrence of Rickettsia spp. and Coxiella bur...     0.0  Journal Article
#
#    id
# 0   0
# 1   1
# 2   2

# %% [markdown]
# Only using rainfall and excluding dengue

# %% [markdown]
# ## Set experiment directory

# %%
exp_root_dir = "../experiments/"
templates_dir = join(exp_root_dir, "templates")
results_root_dir = join(exp_root_dir, "results")
reports_root_dir = join(exp_root_dir, "reports")
review_root_dir = join(exp_root_dir, "review")

#Regular expression to extract out the different parts of the file name. Using _ as a delimiter
reg_exp_file_template = re.compile("(?P<model>[A-za-z0-9-]+)_(?P<exp>[A-za-z0-9-]+).txt")

# %% [markdown]
# ## Run the model

# %%
template_name = 'gpt-4o-mini_h-05-single-answer-4.txt'

components = reg_exp_file_template.search(template_name).groupdict()
model_alias, exp = components.values()
info = cr.MODEL_INFOS[model_alias]

print(f"Initializing to run '{model_alias}' using '{template_name}' template")

promptGenerator = cr.QAPromptGenerator(join(templates_dir, template_name))

llmClient = cr.AsyncLLMClient(info, cr.SINGLE_LEVEL_QA_RESPONSE)

runner = cr.ExperimentRunner(promptGenerator, llmClient, results_root_dir)
await runner.async_run(df_sample, model_alias, exp)

# %% [markdown]
# ## Process results

# %% [markdown]
# ### Read the results

# %%
exp_to_load = ['/h-05-single-answer-4/']

csv_col_map = {
    0: 'id',
    1: 'response'
}

ans_map = {
    'definitely yes': 0.95,
    'probably yes': 0.75,
    'probably no': 0.25,
    'definitely no': 0.05
}

# %%
def parse_answers(response):
    # Parse the JSON string
    try:
        response_json = json.loads(response)
        
    except Exception as e:
        print(f"Error: An unexpected error occurred for request: {e}\n{response}")
        response_json = { "results": [] }
    
    
    # Initialize a dictionary to store answers for each question
    answer_dict = {}
    
    # Loop through the 'results' to extract answers
    for result in response_json['results']:
        question_num = result['question_number']     
        reason_text = result['reason'] 
        ans_text = result['answer'].lower()

        answer_dict[f'reason_{question_num}'] = reason_text

        # map the answer - if not 'yes' or 'no' then default to 0.5
        answer_dict[f'answer_{question_num}'] = ans_map.get(ans_text, 0.5)
        
    return pd.Series(answer_dict)

# %%
df_comb_results = cr.process_results(df_sample, exp_to_load, results_root_dir, parse_answers)
df_comb_results.head(5)
# Out:
# Reading - ../experiments/results/gpt-4o-mini/h-05-single-answer-4/cchf-rainfall
# Reading - ../experiments/results/gpt-4o-mini/h-05-single-answer-4/ebola-rainfall
# Reading - ../experiments/results/gpt-4o-mini/h-05-single-answer-4/lepto-rainfall
# Reading - ../experiments/results/gpt-4o-mini/h-05-single-answer-4/rvf-rainfall
# There are 2905 rows in this dataset.
#    id            experiment        model disease  variable  \
# 0   7  h-05-single-answer-4  gpt-4o-mini    cchf  rainfall
# 1   0  h-05-single-answer-4  gpt-4o-mini    cchf  rainfall
# 2   4  h-05-single-answer-4  gpt-4o-mini    cchf  rainfall
# 3   6  h-05-single-answer-4  gpt-4o-mini    cchf  rainfall
# 4   3  h-05-single-answer-4  gpt-4o-mini    cchf  rainfall
#
#                                             reason_1  answer_1  \
# 0  The abstract discusses a review of modern vacc...      0.05
# 1  The abstract indicates that it is a report pro...      0.05
# 2  The abstract describes a study that involves t...      0.95
# 3  The study investigates a specific outbreak of ...      0.95
# 4  The abstract indicates that it is a review of ...      0.05
#
#                                             reason_2  answer_2  \
# 0  The abstract does not mention Crimean-Congo ha...      0.05
# 1  The study discusses the role of tick vectors a...      0.05
# 2  The study focuses on the Rift Valley fever vir...      0.05
# 3  The study focuses on Rift Valley fever virus (...      0.05
# 4  The abstract discusses vector-borne diseases i...      0.05
#
#                                             reason_3  answer_3  \
# 0  The abstract does not address environmental fa...      0.05
# 1  The abstract mentions factors such as fragment...      0.05
# 2  The abstract does not mention any environmenta...      0.05
# 3  The abstract discusses the emergence of RVFV i...      0.75
# 4  The abstract mentions environmental conditions...      0.25
#
#                                             reason_4  answer_4  tag  \
# 0  The study is a review and opinion piece, not f...      0.05  0.0
# 1  The focus of the study is on the epidemiology ...      0.75  0.0
# 2  The research is centered on identifying T-cell...      0.05  0.0
# 3  The research is based on field data from patie...      0.95  0.0
# 4  The study focuses on the implications of clima...      0.75  0.0
#
#          reference
# 0  Journal Article
# 1  Journal Article
# 2  Journal Article
# 3  Journal Article
# 4  Journal Article

# %% [markdown]
# ### Calculate Ranking

# %%
selected_columns = [col for col in df_comb_results.columns if col in ['id', 'experiment', 'model', 'disease', 'variable', 'tag'] or col.startswith('answer_')]
df_rerank = df_comb_results[selected_columns].copy()

qscore_columns = [col for col in df_rerank.columns if col.startswith('answer_')]
df_rerank['answer_mean'] = df_rerank[qscore_columns].mean(axis=1)
df_rerank.head(5)
# Out:
#    id            experiment        model disease  variable  answer_1  \
# 0   7  h-05-single-answer-4  gpt-4o-mini    cchf  rainfall      0.05
# 1   0  h-05-single-answer-4  gpt-4o-mini    cchf  rainfall      0.05
# 2   4  h-05-single-answer-4  gpt-4o-mini    cchf  rainfall      0.95
# 3   6  h-05-single-answer-4  gpt-4o-mini    cchf  rainfall      0.95
# 4   3  h-05-single-answer-4  gpt-4o-mini    cchf  rainfall      0.05
#
#    answer_2  answer_3  answer_4  tag  answer_mean
# 0      0.05      0.05      0.05  0.0        0.050
# 1      0.05      0.05      0.75  0.0        0.225
# 2      0.05      0.05      0.05  0.0        0.275
# 3      0.05      0.75      0.95  0.0        0.675
# 4      0.05      0.25      0.75  0.0        0.275

# %%
df_comb_results = cr.apply_len_tie_breaker(df_sample, df_rerank, 'answer_mean')
df_comb_results.head(5)
# Out:
#     id            experiment        model disease  variable  answer_1  \
# 0  441  h-05-single-answer-4  gpt-4o-mini    cchf  rainfall      0.95
# 1   20  h-05-single-answer-4  gpt-4o-mini    cchf  rainfall      0.95
# 2  285  h-05-single-answer-4  gpt-4o-mini    cchf  rainfall      0.95
# 3  407  h-05-single-answer-4  gpt-4o-mini    cchf  rainfall      0.95
# 4  243  h-05-single-answer-4  gpt-4o-mini    cchf  rainfall      0.95
#
#    answer_2  answer_3  answer_4  tag  answer_mean  \
# 0      0.95      0.95      0.95  1.0         0.95
# 1      0.95      0.95      0.95  1.0         0.95
# 2      0.95      0.95      0.95  1.0         0.95
# 3      0.75      0.95      0.95  1.0         0.90
# 4      0.75      0.95      0.95  1.0         0.90
#
#                                               target  target_len  ranking
# 0  Temporal tendency, seasonality and relationshi...        2385        1
# 1  Crimean-Congo hemorrhagic fever and its relati...        1657        2
# 2  The effect of climate variables on the inciden...        1456        3
# 3  Epidemiological Community and Differences of T...        3765        4
# 4  Distribution and molecular identification of i...        3446        5

# %% [markdown]
# ## Review Document

# %% [markdown]
# Creating a CSV file for reviewing the results.

# %%
selected_columns = [col for col in df_comb_results.columns if col in ['id', 'experiment', 'model'] or col.startswith('reason_') ]
df_review_ref = pd.merge(
    df_comb_results[selected_columns], 
    df_sample[['id', 'target']], 
    how='left',
    left_on='id', 
    right_on='id'
)

df_review = pd.merge(
    df_comb_results,
    df_review_ref, 
    how='left',
    left_on=['id', 'experiment', 'model'], 
    right_on=['id', 'experiment', 'model']
)

# %% [markdown]
# Creating separate files for each experiment

# %%
print(df_review.shape)
groups = df_review.groupby(["model", "experiment"])
for key, data in groups:
    print(f"{key[0]} - {key[1]}")
    df_output = df_review.query(f"model == '{key[0]}' & experiment == '{key[1]}'")
    print(df_output.shape)
    df_output.to_csv(review_root_dir + f'/review_h-01_{key[0]}_{key[1]}.csv', header=True, index=False, encoding='utf-8')

    #reporting
    df_reporting = df_output[['id', 'experiment', 'model', 'disease', 'variable', 'tag', 'answer_mean', 'ranking']].copy()
    df_reporting.rename(columns={"answer_mean": "score"}, inplace=True)
    df_reporting.to_csv(reports_root_dir + f'/report_{key[0]}_{key[1]}.csv', header=True, index=False, encoding='utf-8')
# Out:
# (2905, 15)
# gpt-4o-mini - h-05-single-answer-4
# (2905, 15)
